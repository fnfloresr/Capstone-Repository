# %% [markdown]
# <a href="https://colab.research.google.com/github/fnfloresr/Capstone-Repository/blob/main/Foursquare_Example_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example 1

# %%
import requests
import pandas as pd 
import numpy as np
import random

# %%
! pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.6/dist-packages (1.17.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.6/dist-packages (from geopy) (1.50)

# %%
from geopy.geocoders import Nominatim

# %%
from IPython.display import Image
from IPython.core.display import HTML

# %%
from pandas.io.json import json_normalize

# %%
! pip install folium
print('')
print('ok')
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from folium) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from folium) (2.23.0)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from folium) (0.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from folium) (1.19.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->folium) (1.1.1)
#
# ok

# %%
asa = "2-6-7 Asakusa, Tokyo, 111-0032, Japan"
shin = "1-20-2 Shinjuku, Shinjuku-ku, Tokyo, 160-0021, Japan"

# %%
geolocator = Nominatim(user_agent="foursquare_agent")

# %%
location_asa = geolocator.geocode(asa)
location_shin = geolocator.geocode(shin)

print(location_asa.latitude, location_asa.longitude)
print(location_shin.latitude, location_shin.longitude)
# Out:
# 35.7090062 139.7964925
# 35.6922273 139.7006009

# %%
CLIENT_ID = '1W4IK1UUMFLM1T3DZ1URW0I15Z01VX4KXVUKLEYWWXWBKTA'
CLIENT_SECRET = 'GPHLVDJ310XIQQFV5RTKZWVVHXMH2Y0NDD3DEKVVOPR35O1C'
ACCESS_TOKEN = 'U1MLLURYOWHM0VMMEEGGMLEQLPDIRJZXXTNXX4XXNNKMJICF'
VERSION = '20210218'
LIMIT = 30

# %%
print('CLIENT_ID = ', CLIENT_ID)
print('CLIENT_SECRET =', CLIENT_SECRET)
print('ACCESS_TOKEN =', ACCESS_TOKEN)
print('VERSION =', VERSION)
print('LIMIT =', LIMIT)
# Out:
# CLIENT_ID =  1W4IK1UUMFLM1T3DZ1URW0I15Z01VX4KXVUKLEYWWXWBKTA
# CLIENT_SECRET = GPHLVDJ310XIQQFV5RTKZWVVHXMH2Y0NDD3DEKVVOPR35O1C
# ACCESS_TOKEN = U1MLLURYOWHM0VMMEEGGMLEQLPDIRJZXXTNXX4XXNNKMJICF
# VERSION = 20210218
# LIMIT = 30

# %%
search_query = 'Sushi'
radius = 600
print(search_query + '....ok!')
# Out:
# Sushi....ok!

# %%
url_asa = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, location_asa.latitude, location_asa.longitude, ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)

# %%
url_asa
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=1W4IK1UUMFLM1T3DZ1URW0I15Z01VX4KXVUKLEYWWXWBKTA&client_secret=GPHLVDJ310XIQQFV5RTKZWVVHXMH2Y0NDD3DEKVVOPR35O1C&ll=35.7090062,139.7964925&oauth_token=U1MLLURYOWHM0VMMEEGGMLEQLPDIRJZXXTNXX4XXNNKMJICF&v=20210218&query=Sushi&radius=600&limit=30'

# %%
results_asa = requests.get(url_asa).json()
results_asa
# Out:
# {'meta': {'code': 200, 'requestId': '602eb5944ff54e0befe66a04'},
#  'notifications': [{'item': {'unreadCount': 0}, 'type': 'notificationTray'}],
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4f674ba5e4b062549dad765a',
#     'location': {'address': '西浅草2-13-9',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': 'MC浅草ビル 1F',
#      'distance': 569,
#      'formattedAddress': ['西浅草2-13-9 (MC浅草ビル 1F)',
#       '台東区, 東京都',
#       '111-0035',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.712552,
#        'lng': 139.791946}],
#      'lat': 35.712552,
#      'lng': 139.791946,
#      'postalCode': '111-0035',
#      'state': '東京都'},
#     'name': 'Sushiichiban (築地 すし一番 西浅草店)',
#     'referralId': 'v-1613673877'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4ebd3f1ab8f7b504a75f19e8',
#     'location': {'address': '雷門2-16-9',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': 'パゴダ浅草 1F-2F',
#      'distance': 249,
#      'formattedAddress': ['雷門2-16-9 (パゴダ浅草 1F-2F)',
#       '台東区, 東京都',
#       '111-0034',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.710894221997364,
#        'lng': 139.79499980807304}],
#      'lat': 35.710894221997364,
#      'lng': 139.79499980807304,
#      'postalCode': '111-0034',
#      'state': '東京都'},
#     'name': 'Tsukiji Sushi Sen (築地すし鮮)',
#     'referralId': 'v-1613673877'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '5e281c386fe2f80008d81443',
#     'location': {'address': '浅草1-25-15',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': '浅草ROX 4F',
#      'distance': 519,
#      'formattedAddress': ['浅草1-25-15 (浅草ROX 4F)',
#       '台東区, 東京都',
#       '111-0032',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.71264,
#        'lng': 139.79288}],
#      'lat': 35.71264,
#      'lng': 139.79288,
#      'neighborhood': '浅草',
#      'postalCode': '111-0032',
#      'state': '東京都'},
#     'name': 'Kura Sushi (くら寿司)',
#     'referralId': 'v-1613673877'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '5d42a0e02b09730007cae65d',
#     'location': {'address': '浅草1-21-3',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': 'エリカビル 2F',
#      'distance': 334,
#      'formattedAddress': ['浅草1-21-3 (エリカビル 2F)', '台東区, 東京都', '111-0032', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.711742,
#        'lng': 139.794973}],
#      'lat': 35.711742,
#      'lng': 139.794973,
#      'postalCode': '111-0032',
#      'state': '東京都'},
#     'name': 'Sushi Reiwa (寿司 令和)',
#     'referralId': 'v-1613673877'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4c91f6ac7f3b8cfa97d5a01e',
#     'location': {'address': '浅草2-11-4',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'distance': 652,
#      'formattedAddress': ['浅草2-11-4', '台東区, 東京都', '111-0032', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.713879522905735,
#        'lng': 139.79249107261907}],
#      'lat': 35.713879522905735,
#      'lng': 139.79249107261907,
#      'postalCode': '111-0032',
#      'state': '東京都'},
#     'name': 'Sushi Ken (浅草すし賢)',
#     'referralId': 'v-1613673877'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '502e0441e4b07d6b3437173a',
#     'location': {'address': '浅草 2-35-13 浅草ＴＯＫｉＳ',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'distance': 580,
#      'formattedAddress': ['浅草 2-35-13 浅草ＴＯＫｉＳ', '台東区, 東京都', '111-0032', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.71409587966257,
#        'lng': 139.79790329933167}],
#      'lat': 35.71409587966257,
#      'lng': 139.79790329933167,
#      'postalCode': '111-0032',
#      'state': '東京都'},
#     'name': 'Sushi Hashiguchi (鮨 橋口)',
#     'referralId': 'v-1613673877'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '54a112df498e80876e7e9d54',
#     'location': {'address': '浅草1-43-9',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': 'レクス浅草 1F-2F',
#      'distance': 604,
#      'formattedAddress': ['浅草1-43-9 (レクス浅草 1F-2F)',
#       '台東区, 東京都',
#       '111-0032',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.713585243338855,
#        'lng': 139.79290591513887}],
#      'lat': 35.713585243338855,
#      'lng': 139.79290591513887,
#      'postalCode': '111-0032',
#      'state': '東京都'},
#     'name': 'Sushi Mamire (築地海鮮 すしまみれ)',
#     'referralId': 'v-1613673877'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '533a7dad498ef2793db5c3df',
#     'location': {'address': '雷門1-3-7',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'distance': 294,
#      'formattedAddress': ['雷門1-3-7', '東京, 東京都', '111-0034', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.710119131113714,
#        'lng': 139.7935339808464}],
#      'lat': 35.710119131113714,
#      'lng': 139.7935339808464,
#      'postalCode': '111-0034',
#      'state': '東京都'},
#     'name': '野八',
#     'referralId': 'v-1613673877'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '510b9e3ee4b06fc52c3d4881',
#     'location': {'address': '花川戸1-4-1',
#      'cc': 'JP',
#      'city': '台東区',
#      'country': '日本',
#      'crossStreet': '浅草エキミセ 7F',
#      'distance': 316,
#      'formattedAddress': ['花川戸1-4-1 (浅草エキミセ 7F)',
#       '台東区, 東京都',
#       '111-0033',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.71157831162301,
#        'lng': 139.79799449443817}],
#      'lat': 35.71157831162301,
#      'lng': 139.79799449443817,
#      'postalCode': '111-0033',
#      'state': '東京都'},
#     'name': 'Tsukiji Tama Sushi (築地玉寿司)',
#     'referralId': 'v-1613673877'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4dcc9fe722718eed7a0bf947',
#     'location': {'address': '花川戸1-2-3',
#      'cc': 'JP',
#      'city': '台東区',
#      'country': '日本',
#      'crossStreet': '浅草駅前',
#      'distance': 257,
#      'formattedAddress': ['花川戸1-2-3 (浅草駅前)', '台東区, 東京都', '111-0033', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.710911,
#        'lng': 139.798112}],
#      'lat': 35.710911,
#      'lng': 139.798112,
#      'postalCode': '111-0033',
#      'state': '東京都'},
#     'name': 'Ganso Zushi (元祖寿司)',
#     'referralId': 'v-1613673877'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4eed592177169cacb37a8d24',
#     'location': {'address': '浅草1-6-5',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'distance': 370,
#      'formattedAddress': ['浅草1-6-5', '台東区, 東京都', '111-0032', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.711578,
#        'lng': 139.793899}],
#      'lat': 35.711578,
#      'lng': 139.793899,
#      'postalCode': '111-0032',
#      'state': '東京都'},
#     'name': 'Mimatsu Sushi Restaurant (三松寿司)',
#     'referralId': 'v-1613673877'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '53202e13498ee2d5cbf6c3fe',
#     'location': {'address': '駒形1-9-5',
#      'cc': 'JP',
#      'city': '台東区',
#      'country': '日本',
#      'distance': 571,
#      'formattedAddress': ['駒形1-9-5', '台東区, 東京都', '111-0043', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.70510887414041,
#        'lng': 139.79237655017138}],
#      'lat': 35.70510887414041,
#      'lng': 139.79237655017138,
#      'postalCode': '111-0043',
#      'state': '東京都'},
#     'name': '鮨 松波',
#     'referralId': 'v-1613673877'}]}}

# %%
url_shin = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, location_shin.latitude, location_shin.longitude, ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url_shin
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=1W4IK1UUMFLM1T3DZ1URW0I15Z01VX4KXVUKLEYWWXWBKTA&client_secret=GPHLVDJ310XIQQFV5RTKZWVVHXMH2Y0NDD3DEKVVOPR35O1C&ll=35.6922273,139.7006009&oauth_token=U1MLLURYOWHM0VMMEEGGMLEQLPDIRJZXXTNXX4XXNNKMJICF&v=20210218&query=Sushi&radius=600&limit=30'

# %%
results_shin = requests.get(url_shin).json()
results_shin
# Out:
# {'meta': {'code': 200, 'requestId': '602ebb02358abb29720e2e90'},
#  'notifications': [{'item': {'unreadCount': 0}, 'type': 'notificationTray'}],
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '571b515a498e92ae02b6322f',
#     'location': {'address': '千駄ヶ谷5-24-55',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': 'NEWoMan 2F フードホール',
#      'distance': 451,
#      'formattedAddress': ['千駄ヶ谷5-24-55 (NEWoMan 2F フードホール)',
#       '渋谷区, 東京都',
#       '151-0051',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.688183905085225,
#        'lng': 139.7002851952733}],
#      'lat': 35.688183905085225,
#      'lng': 139.7002851952733,
#      'neighborhood': '新宿',
#      'postalCode': '151-0051',
#      'state': '東京都'},
#     'name': 'SUSHI TOKYO TEN',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '5a59c8c00a464d6ac461cb5f',
#     'location': {'address': '新宿3-38-1',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': 'ルミネエスト新宿 8F',
#      'distance': 91,
#      'formattedAddress': ['新宿3-38-1 (ルミネエスト新宿 8F)',
#       '新宿区, 東京都',
#       '160-0022',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.691517,
#        'lng': 139.7011}],
#      'lat': 35.691517,
#      'lng': 139.7011,
#      'postalCode': '160-0022',
#      'state': '東京都'},
#     'name': 'Sushi Kotama (すし こたま)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '55fd77df498e0e3093dac5aa',
#     'location': {'address': '新宿3-18-4',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': 'セノビル 3F',
#      'distance': 157,
#      'formattedAddress': ['新宿3-18-4 (セノビル 3F)', '新宿区, 東京都', '160-0022', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.692341,
#        'lng': 139.702335}],
#      'lat': 35.692341,
#      'lng': 139.702335,
#      'postalCode': '160-0022',
#      'state': '東京都'},
#     'name': 'Sushizanmai (すしざんまい)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '511078d2e4b00d021962df2a',
#     'location': {'address': '西新宿1-3-1',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': '新宿サンフラワービル 1F',
#      'distance': 206,
#      'formattedAddress': ['西新宿1-3-1 (新宿サンフラワービル 1F)',
#       '新宿区, 東京都',
#       '160-0023',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.693417779175846,
#        'lng': 139.69884797930717}],
#      'lat': 35.693417779175846,
#      'lng': 139.69884797930717,
#      'postalCode': '160-0023',
#      'state': '東京都'},
#     'name': 'Oedo (回転寿司 大江戸)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4ba4201bf964a520168438e3',
#     'location': {'address': '歌舞伎町1-2-3',
#      'cc': 'JP',
#      'city': '新宿区',
#      'country': '日本',
#      'distance': 326,
#      'formattedAddress': ['歌舞伎町1-2-3', '新宿区, 東京都', '160-0021', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.69358986923683,
#        'lng': 139.70380067825317}],
#      'lat': 35.69358986923683,
#      'lng': 139.70380067825317,
#      'postalCode': '160-0021',
#      'state': '東京都'},
#     'name': 'Sushi Mamire (築地海鮮 すしまみれ)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '5fffcb805856d95fb1f48d8a',
#     'location': {'address': '西新宿7-1-7',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': '新宿ダイカンプラザA館2F',
#      'distance': 275,
#      'formattedAddress': ['西新宿7-1-7 (新宿ダイカンプラザA館2F)',
#       '新宿区, 東京都',
#       '160-0023',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.69434650289613,
#        'lng': 139.69903573393822}],
#      'lat': 35.69434650289613,
#      'lng': 139.69903573393822,
#      'postalCode': '160-0023',
#      'state': '東京都'},
#     'name': 'Kura Sushi (くら寿司)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '5400d137498ed107bea9a86b',
#     'location': {'address': '歌舞伎町1-15-5',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': 'セントラルロード ビッグレモンビル 1F',
#      'distance': 239,
#      'formattedAddress': ['歌舞伎町1-15-5 (セントラルロード ビッグレモンビル 1F)',
#       '新宿区, 東京都',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.69414849565829,
#        'lng': 139.701789021492}],
#      'lat': 35.69414849565829,
#      'lng': 139.701789021492,
#      'state': '東京都'},
#     'name': 'Sushi Mamire (築地海鮮 すしまみれ)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4f0ee9dce4b023b37a478717',
#     'location': {'address': '歌舞伎町1-18-8',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': '第1モナミビル 1F',
#      'distance': 293,
#      'formattedAddress': ['歌舞伎町1-18-8 (第1モナミビル 1F)',
#       '新宿区, 東京都',
#       '160-0021',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.694703,
#        'lng': 139.701732}],
#      'lat': 35.694703,
#      'lng': 139.701732,
#      'postalCode': '160-0021',
#      'state': '東京都'},
#     'name': 'Kizuna Sushi (きづなすし)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4c3699433849c9283569bcb1',
#     'location': {'address': '新宿3-21-4',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'distance': 165,
#      'formattedAddress': ['新宿3-21-4', '新宿区, 東京都', '160-0022', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.693033,
#        'lng': 139.702145}],
#      'lat': 35.693033,
#      'lng': 139.702145,
#      'postalCode': '160-0022',
#      'state': '東京都'},
#     'name': 'Ougi Sushi (扇寿司)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sake_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11c941735',
#       'name': 'Sake Bar',
#       'pluralName': 'Sake Bars',
#       'primary': True,
#       'shortName': 'Sake Bar'}],
#     'hasPerk': False,
#     'id': '4b7d2f31f964a520b7b12fe3',
#     'location': {'address': '歌舞伎町2-35-2',
#      'cc': 'JP',
#      'city': '新宿区',
#      'country': '日本',
#      'distance': 466,
#      'formattedAddress': ['歌舞伎町2-35-2', '新宿区, 東京都', '160-0021', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.696118145614285,
#        'lng': 139.7025067240167}],
#      'lat': 35.696118145614285,
#      'lng': 139.7025067240167,
#      'postalCode': '160-0021',
#      'state': '東京都'},
#     'name': 'Sushi Izakaya Alps (すし居酒屋 アルプス)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '556ad586498e03cd34957923',
#     'location': {'address': '新宿3-17-7',
#      'cc': 'JP',
#      'city': '新宿区',
#      'country': '日本',
#      'crossStreet': '紀伊國屋ビル B1F',
#      'distance': 213,
#      'formattedAddress': ['新宿3-17-7 (紀伊國屋ビル B1F)',
#       '新宿区, 東京都',
#       '160-0022',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.69222185239619,
#        'lng': 139.70296508058317}],
#      'lat': 35.69222185239619,
#      'lng': 139.70296508058317,
#      'neighborhood': '新宿区, 東京, 東京都',
#      'postalCode': '160-0022',
#      'state': '東京都'},
#     'name': 'Sushi Misakimaru (すし三崎丸)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4c1db4f98b3aa593391b9b5f',
#     'location': {'address': '新宿3-14-1',
#      'cc': 'JP',
#      'city': '新宿区',
#      'country': '日本',
#      'crossStreet': '伊勢丹新宿店 7F',
#      'distance': 387,
#      'formattedAddress': ['新宿3-14-1 (伊勢丹新宿店 7F)',
#       '新宿区, 東京都',
#       '160-0022',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.691277668653555,
#        'lng': 139.70472913243609}],
#      'lat': 35.691277668653555,
#      'lng': 139.70472913243609,
#      'postalCode': '160-0022',
#      'state': '東京都'},
#     'name': 'Sushi Rosan (鮨 魯山)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '59883ac4f5e9d71716112f71',
#     'location': {'address': '西新宿1',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': '小田急エース 北館東',
#      'distance': 167,
#      'formattedAddress': ['西新宿1 (小田急エース 北館東)', '新宿区, 東京都', '160-0023', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.691650022431645,
#        'lng': 139.69888687133786}],
#      'lat': 35.691650022431645,
#      'lng': 139.69888687133786,
#      'neighborhood': '西新宿',
#      'postalCode': '160-0023',
#      'state': '東京都'},
#     'name': 'Hokkai-Sushi Unimaru (北海寿司 うに丸)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4ff43c70e4b048eef684da52',
#     'location': {'address': '西新宿7-13-6',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': 'ササオハウス 1F',
#      'distance': 423,
#      'formattedAddress': ['西新宿7-13-6 (ササオハウス 1F)',
#       '新宿区, 東京都',
#       '160-0023',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.69380318168475,
#        'lng': 139.69633999474104}],
#      'lat': 35.69380318168475,
#      'lng': 139.69633999474104,
#      'postalCode': '160-0023',
#      'state': '東京都'},
#     'name': 'Sushi Sagane (鮨 さがね)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4e83e3507ee6f75ca2df1144',
#     'location': {'address': '西新宿1-6-1',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': '新宿エルタワー B2F',
#      'distance': 299,
#      'formattedAddress': ['西新宿1-6-1 (新宿エルタワー B2F)',
#       '新宿区, 東京都',
#       '160-0023',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.69219462203097,
#        'lng': 139.69729363918304}],
#      'lat': 35.69219462203097,
#      'lng': 139.69729363918304,
#      'postalCode': '160-0023',
#      'state': '東京都'},
#     'name': 'Sushi Ishikawa (鮨いしかわ)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4b7532a3f964a520e1002ee3',
#     'location': {'address': '西新宿1-12',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': '河西ビル 1F',
#      'distance': 387,
#      'formattedAddress': ['西新宿1-12 (河西ビル 1F)', '新宿区, 東京都', '160-0023', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.6900127,
#        'lng': 139.6972963}],
#      'lat': 35.6900127,
#      'lng': 139.6972963,
#      'postalCode': '160-0023',
#      'state': '東京都'},
#     'name': 'Uogashi Nihon-ichi (魚がし日本一)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4b5f66d6f964a5203db829e3',
#     'location': {'address': '西新宿1-1',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': '新宿京王モール エリアA',
#      'distance': 337,
#      'formattedAddress': ['西新宿1-1 (新宿京王モール エリアA)',
#       '新宿区, 東京都',
#       '160-0023',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.68961568701986,
#        'lng': 139.6987012749794}],
#      'lat': 35.68961568701986,
#      'lng': 139.6987012749794,
#      'postalCode': '160-0023',
#      'state': '東京都'},
#     'name': 'Sushi Misakimaru (すし三崎丸)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '5813ff0538fa25270e80bec2',
#     'location': {'address': '西新宿1-1-5',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': 'ルミネ新宿1 B2F',
#      'distance': 400,
#      'formattedAddress': ['西新宿1-1-5 (ルミネ新宿1 B2F)',
#       '新宿区, 東京都',
#       '160-0023',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.68889141492929,
#        'lng': 139.69893294029998}],
#      'lat': 35.68889141492929,
#      'lng': 139.69893294029998,
#      'postalCode': '160-0023',
#      'state': '東京都'},
#     'name': 'Sushi Takewaka (すし たけわか)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4cee19dc4cd4236a8625ac63',
#     'location': {'address': '歌舞伎町1-7-5',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'distance': 326,
#      'formattedAddress': ['歌舞伎町1-7-5', '新宿区, 東京都', '160-0021', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.69448462265168,
#        'lng': 139.70290884375572}],
#      'lat': 35.69448462265168,
#      'lng': 139.70290884375572,
#      'postalCode': '160-0021',
#      'state': '東京都'},
#     'name': 'すし半',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '51fdd4db498e2025d68a83c0',
#     'location': {'address': '新宿3-14-1',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'distance': 336,
#      'formattedAddress': ['新宿3-14-1', '新宿区, 東京都', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.69116271427364,
#        'lng': 139.70408860249594}],
#      'lat': 35.69116271427364,
#      'lng': 139.70408860249594,
#      'state': '東京都'},
#     'name': "スシ・アベニュー K's",
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4e0f125be4cd27fc7d359179',
#     'location': {'address': '歌舞伎町1-25-3',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'distance': 249,
#      'formattedAddress': ['歌舞伎町1-25-3', '新宿区, 東京都', '160-0021', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.69446322715062,
#        'lng': 139.7004454700925}],
#      'lat': 35.69446322715062,
#      'lng': 139.7004454700925,
#      'postalCode': '160-0021',
#      'state': '東京都'},
#     'name': 'Sakura Sushi (桜すし)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4e2151ee45dd950bb023dc4f',
#     'location': {'address': '西新宿2-2-1',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': '京王プラザホテル 本館 7F',
#      'distance': 533,
#      'formattedAddress': ['西新宿2-2-1 (京王プラザホテル 本館 7F)',
#       '新宿区, 東京都',
#       '160-8330',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.690372623885935,
#        'lng': 139.69515996139285}],
#      'lat': 35.690372623885935,
#      'lng': 139.69515996139285,
#      'postalCode': '160-8330',
#      'state': '東京都'},
#     'name': 'Kyubey (久兵衛)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4cd3741a9828b60c6ed3d584',
#     'location': {'address': '西新宿6-2-3',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': 'アイランドアネックス 1F',
#      'distance': 582,
#      'formattedAddress': ['西新宿6-2-3 (アイランドアネックス 1F)',
#       '新宿区, 東京都',
#       '160-0023',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.69367992140472,
#        'lng': 139.6944099814713}],
#      'lat': 35.69367992140472,
#      'lng': 139.6944099814713,
#      'postalCode': '160-0023',
#      'state': '東京都'},
#     'name': '誠寿司',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'primary': True,
#       'shortName': 'Deli / Bodega'}],
#     'hasPerk': False,
#     'id': '4d565acdba5b224ba89e1914',
#     'location': {'address': '新宿3-14-1',
#      'cc': 'JP',
#      'city': '新宿区',
#      'country': '日本',
#      'crossStreet': '伊勢丹新宿店 B1F',
#      'distance': 388,
#      'formattedAddress': ['新宿3-14-1 (伊勢丹新宿店 B1F)', '新宿区, 東京都', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.691696313542195,
#        'lng': 139.704852104187}],
#      'lat': 35.691696313542195,
#      'lng': 139.704852104187,
#      'state': '東京都'},
#     'name': 'Kanda Shinoda Sushi (神田志乃多寿司)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4bfdec888992a593b7eaacb0',
#     'location': {'address': '新宿3-35-10',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': 'ロイヤルプリンスビル 1F',
#      'distance': 286,
#      'formattedAddress': ['新宿3-35-10 (ロイヤルプリンスビル 1F)',
#       '新宿区, 東京都',
#       '160-0022',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.690023,
#        'lng': 139.702238}],
#      'lat': 35.690023,
#      'lng': 139.702238,
#      'postalCode': '160-0022',
#      'state': '東京都'},
#     'name': 'Oedo (回転寿司 大江戸)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '55406bfa498ec98db000ca19',
#     'location': {'address': '歌舞伎町1-19-1',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': '新宿東宝ビル 1F',
#      'distance': 350,
#      'formattedAddress': ['歌舞伎町1-19-1 (新宿東宝ビル 1F)',
#       '新宿区, 東京都',
#       '160-0021',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.69525809540629,
#        'lng': 139.70164501989044}],
#      'lat': 35.69525809540629,
#      'lng': 139.70164501989044,
#      'postalCode': '160-0021',
#      'state': '東京都'},
#     'name': 'Itamae Sushi (板前寿司)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '557acb87498ec5a5a9149b9f',
#     'location': {'address': '西新宿7-9-15',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': '新宿ダイカンプラザビジネス清田 1F',
#      'distance': 359,
#      'formattedAddress': ['西新宿7-9-15 (新宿ダイカンプラザビジネス清田 1F)', '新宿区, 東京都', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.69485858964133,
#        'lng': 139.69829730408543}],
#      'lat': 35.69485858964133,
#      'lng': 139.69829730408543,
#      'state': '東京都'},
#     'name': 'Nigirite Standing Sushi Bar (立喰い寿司 にぎりて)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4bfd167be529c928db56ba8c',
#     'location': {'address': '新宿5-17-11',
#      'cc': 'JP',
#      'city': '新宿区',
#      'country': '日本',
#      'crossStreet': '白鳳ビル 1F',
#      'distance': 442,
#      'formattedAddress': ['新宿5-17-11 (白鳳ビル 1F)', '新宿区, 東京都', '160-0022', '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.6927194,
#        'lng': 139.7054543}],
#      'lat': 35.6927194,
#      'lng': 139.7054543,
#      'postalCode': '160-0022',
#      'state': '東京都'},
#     'name': 'Tsukiji Sushi-Ko (築地すし好)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4f011a739adffb90ce2e4a37',
#     'location': {'address': '新宿3-15-17',
#      'cc': 'JP',
#      'city': '新宿区',
#      'country': '日本',
#      'crossStreet': '伊勢丹会館 3F',
#      'distance': 313,
#      'formattedAddress': ['新宿3-15-17 (伊勢丹会館 3F)',
#       '新宿区, 東京都',
#       '160-0022',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.692344404445635,
#        'lng': 139.7040606619719}],
#      'lat': 35.692344404445635,
#      'lng': 139.7040606619719,
#      'postalCode': '160-0022',
#      'state': '東京都'},
#     'name': 'Tsukiji Sushisei (築地寿司清)',
#     'referralId': 'v-1613675266'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '56060e9a498ea7032469ffec',
#     'location': {'address': '新宿3-34-16',
#      'cc': 'JP',
#      'city': '東京',
#      'country': '日本',
#      'crossStreet': '池田プラザビル 1F',
#      'distance': 307,
#      'formattedAddress': ['新宿3-34-16 (池田プラザビル 1F)',
#       '新宿区, 東京都',
#       '160-0022',
#       '日本'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 35.690387,
#        'lng': 139.703143}],
#      'lat': 35.690387,
#      'lng': 139.703143,
#      'postalCode': '160-0022',
#      'state': '東京都'},
#     'name': 'Numazuko (回転寿司 沼津港)',
#     'referralId': 'v-1613675266'}]}}

# %%
venues_asa = results_asa['response']['venues']
df_asa = json_normalize(venues_asa)
df_asa
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                           id  ... location.neighborhood
# 0   4f674ba5e4b062549dad765a  ...                   NaN
# 1   4ebd3f1ab8f7b504a75f19e8  ...                   NaN
# 2   5e281c386fe2f80008d81443  ...                    浅草
# 3   5d42a0e02b09730007cae65d  ...                   NaN
# 4   4c91f6ac7f3b8cfa97d5a01e  ...                   NaN
# 5   502e0441e4b07d6b3437173a  ...                   NaN
# 6   54a112df498e80876e7e9d54  ...                   NaN
# 7   533a7dad498ef2793db5c3df  ...                   NaN
# 8   510b9e3ee4b06fc52c3d4881  ...                   NaN
# 9   4dcc9fe722718eed7a0bf947  ...                   NaN
# 10  4eed592177169cacb37a8d24  ...                   NaN
# 11  53202e13498ee2d5cbf6c3fe  ...                   NaN
#
# [12 rows x 18 columns]

# %%
df_asa.drop(columns=['categories','hasPerk','location.address','referralId','location.crossStreet','location.labeledLatLngs','location.postalCode','location.cc','location.city','location.state','location.distance','location.country','location.neighborhood','location.formattedAddress'])
# Out:
#                           id  ... location.lng
# 0   4f674ba5e4b062549dad765a  ...   139.791946
# 1   4ebd3f1ab8f7b504a75f19e8  ...   139.795000
# 2   5e281c386fe2f80008d81443  ...   139.792880
# 3   5d42a0e02b09730007cae65d  ...   139.794973
# 4   4c91f6ac7f3b8cfa97d5a01e  ...   139.792491
# 5   502e0441e4b07d6b3437173a  ...   139.797903
# 6   54a112df498e80876e7e9d54  ...   139.792906
# 7   533a7dad498ef2793db5c3df  ...   139.793534
# 8   510b9e3ee4b06fc52c3d4881  ...   139.797994
# 9   4dcc9fe722718eed7a0bf947  ...   139.798112
# 10  4eed592177169cacb37a8d24  ...   139.793899
# 11  53202e13498ee2d5cbf6c3fe  ...   139.792377
#
# [12 rows x 4 columns]

# %%
df_asa.drop(columns=['categories','hasPerk','location.address','referralId','location.crossStreet','location.labeledLatLngs','location.postalCode','location.cc','location.city','location.state','location.distance','location.country','location.neighborhood','location.formattedAddress'])

# %%
venues_shin = results_shin['response']['venues']
df_shin = json_normalize(venues_shin)
df_shin
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                           id  ...                          location.formattedAddress
# 0   571b515a498e92ae02b6322f  ...  [千駄ヶ谷5-24-55 (NEWoMan 2F フードホール), 渋谷区, 東京都, 15...
# 1   5a59c8c00a464d6ac461cb5f  ...   [新宿3-38-1 (ルミネエスト新宿 8F), 新宿区, 東京都, 160-0022, 日本]
# 2   55fd77df498e0e3093dac5aa  ...       [新宿3-18-4 (セノビル 3F), 新宿区, 東京都, 160-0022, 日本]
# 3   511078d2e4b00d021962df2a  ...  [西新宿1-3-1 (新宿サンフラワービル 1F), 新宿区, 東京都, 160-0023,...
# 4   4ba4201bf964a520168438e3  ...                [歌舞伎町1-2-3, 新宿区, 東京都, 160-0021, 日本]
# 5   5fffcb805856d95fb1f48d8a  ...  [西新宿7-1-7 (新宿ダイカンプラザA館2F), 新宿区, 東京都, 160-0023,...
# 6   5400d137498ed107bea9a86b  ...  [歌舞伎町1-15-5 (セントラルロード ビッグレモンビル 1F), 新宿区, 東京都, 日本]
# 7   4f0ee9dce4b023b37a478717  ...  [歌舞伎町1-18-8 (第1モナミビル 1F), 新宿区, 東京都, 160-0021, 日本]
# 8   4c3699433849c9283569bcb1  ...                 [新宿3-21-4, 新宿区, 東京都, 160-0022, 日本]
# 9   4b7d2f31f964a520b7b12fe3  ...               [歌舞伎町2-35-2, 新宿区, 東京都, 160-0021, 日本]
# 10  556ad586498e03cd34957923  ...    [新宿3-17-7 (紀伊國屋ビル B1F), 新宿区, 東京都, 160-0022, 日本]
# 11  4c1db4f98b3aa593391b9b5f  ...     [新宿3-14-1 (伊勢丹新宿店 7F), 新宿区, 東京都, 160-0022, 日本]
# 12  59883ac4f5e9d71716112f71  ...        [西新宿1 (小田急エース 北館東), 新宿区, 東京都, 160-0023, 日本]
# 13  4ff43c70e4b048eef684da52  ...    [西新宿7-13-6 (ササオハウス 1F), 新宿区, 東京都, 160-0023, 日本]
# 14  4e83e3507ee6f75ca2df1144  ...   [西新宿1-6-1 (新宿エルタワー B2F), 新宿区, 東京都, 160-0023, 日本]
# 15  4b7532a3f964a520e1002ee3  ...        [西新宿1-12 (河西ビル 1F), 新宿区, 東京都, 160-0023, 日本]
# 16  4b5f66d6f964a5203db829e3  ...    [西新宿1-1 (新宿京王モール エリアA), 新宿区, 東京都, 160-0023, 日本]
# 17  5813ff0538fa25270e80bec2  ...    [西新宿1-1-5 (ルミネ新宿1 B2F), 新宿区, 東京都, 160-0023, 日本]
# 18  4cee19dc4cd4236a8625ac63  ...                [歌舞伎町1-7-5, 新宿区, 東京都, 160-0021, 日本]
# 19  51fdd4db498e2025d68a83c0  ...                           [新宿3-14-1, 新宿区, 東京都, 日本]
# 20  4e0f125be4cd27fc7d359179  ...               [歌舞伎町1-25-3, 新宿区, 東京都, 160-0021, 日本]
# 21  4e2151ee45dd950bb023dc4f  ...  [西新宿2-2-1 (京王プラザホテル 本館 7F), 新宿区, 東京都, 160-8330...
# 22  4cd3741a9828b60c6ed3d584  ...  [西新宿6-2-3 (アイランドアネックス 1F), 新宿区, 東京都, 160-0023,...
# 23  4d565acdba5b224ba89e1914  ...              [新宿3-14-1 (伊勢丹新宿店 B1F), 新宿区, 東京都, 日本]
# 24  4bfdec888992a593b7eaacb0  ...  [新宿3-35-10 (ロイヤルプリンスビル 1F), 新宿区, 東京都, 160-0022...
# 25  55406bfa498ec98db000ca19  ...   [歌舞伎町1-19-1 (新宿東宝ビル 1F), 新宿区, 東京都, 160-0021, 日本]
# 26  557acb87498ec5a5a9149b9f  ...     [西新宿7-9-15 (新宿ダイカンプラザビジネス清田 1F), 新宿区, 東京都, 日本]
# 27  4bfd167be529c928db56ba8c  ...      [新宿5-17-11 (白鳳ビル 1F), 新宿区, 東京都, 160-0022, 日本]
# 28  4f011a739adffb90ce2e4a37  ...     [新宿3-15-17 (伊勢丹会館 3F), 新宿区, 東京都, 160-0022, 日本]
# 29  56060e9a498ea7032469ffec  ...   [新宿3-34-16 (池田プラザビル 1F), 新宿区, 東京都, 160-0022, 日本]
#
# [30 rows x 18 columns]

# %%
df_shin.drop(columns=['categories','hasPerk','location.address','referralId','location.crossStreet','location.labeledLatLngs','location.postalCode','location.cc','location.city','location.state','location.distance','location.country','location.neighborhood','location.formattedAddress'])
# Out:
#                           id  ... location.lng
# 0   571b515a498e92ae02b6322f  ...   139.700285
# 1   5a59c8c00a464d6ac461cb5f  ...   139.701100
# 2   55fd77df498e0e3093dac5aa  ...   139.702335
# 3   511078d2e4b00d021962df2a  ...   139.698848
# 4   4ba4201bf964a520168438e3  ...   139.703801
# 5   5fffcb805856d95fb1f48d8a  ...   139.699036
# 6   5400d137498ed107bea9a86b  ...   139.701789
# 7   4f0ee9dce4b023b37a478717  ...   139.701732
# 8   4c3699433849c9283569bcb1  ...   139.702145
# 9   4b7d2f31f964a520b7b12fe3  ...   139.702507
# 10  556ad586498e03cd34957923  ...   139.702965
# 11  4c1db4f98b3aa593391b9b5f  ...   139.704729
# 12  59883ac4f5e9d71716112f71  ...   139.698887
# 13  4ff43c70e4b048eef684da52  ...   139.696340
# 14  4e83e3507ee6f75ca2df1144  ...   139.697294
# 15  4b7532a3f964a520e1002ee3  ...   139.697296
# 16  4b5f66d6f964a5203db829e3  ...   139.698701
# 17  5813ff0538fa25270e80bec2  ...   139.698933
# 18  4cee19dc4cd4236a8625ac63  ...   139.702909
# 19  51fdd4db498e2025d68a83c0  ...   139.704089
# 20  4e0f125be4cd27fc7d359179  ...   139.700445
# 21  4e2151ee45dd950bb023dc4f  ...   139.695160
# 22  4cd3741a9828b60c6ed3d584  ...   139.694410
# 23  4d565acdba5b224ba89e1914  ...   139.704852
# 24  4bfdec888992a593b7eaacb0  ...   139.702238
# 25  55406bfa498ec98db000ca19  ...   139.701645
# 26  557acb87498ec5a5a9149b9f  ...   139.698297
# 27  4bfd167be529c928db56ba8c  ...   139.705454
# 28  4f011a739adffb90ce2e4a37  ...   139.704061
# 29  56060e9a498ea7032469ffec  ...   139.703143
#
# [30 rows x 4 columns]
